# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import matplotlib.dates as md

# %%
df=pd.read_csv('deccanpollution.csv')
df.head()
# Out:
#          created_at  entry_id    Mumbai  Hyderabad   Chennai
# 0  2024-01-31 07:59    167601  1.983746   2.874921  2.694570
# 1  2024-01-31 08:00    167602  1.988521   2.875727  2.697794
# 2  2024-01-31 08:00    167603  1.992550   2.878136  2.700211
# 3  2024-01-31 08:01    167604  1.995774   2.878136  2.702629
# 4  2024-01-31 08:02    167605  1.999791   2.878136  2.704241

# %%
df.drop("entry_id",axis=1,inplace=True)
df.head()
# Out:
#          created_at    Mumbai  Hyderabad   Chennai
# 0  2024-01-31 07:59  1.983746   2.874921  2.694570
# 1  2024-01-31 08:00  1.988521   2.875727  2.697794
# 2  2024-01-31 08:00  1.992550   2.878136  2.700211
# 3  2024-01-31 08:01  1.995774   2.878136  2.702629
# 4  2024-01-31 08:02  1.999791   2.878136  2.704241

# %%
#finding out the time when max at mumbai
df[df['Mumbai']==1.979964835].drop(['Hyderabad','Chennai'],axis=1)
# Out:
#           created_at    Mumbai
# 30  2024-01-31 08:20  1.979965

# %%
 #finding out the time when max. pollution occurs at hydrabad
df[df['Hyderabad']==2.869090842].drop(['Mumbai','Chennai'],axis=1)
# Out:
#           created_at  Hyderabad
# 42  2024-01-31 08:33   2.869091

# %%
 #finding out the time when max. pollution occurs at chennai
df[df['Chennai']==2.705852381].drop(['Mumbai','Hyderabad'],axis=1)
# Out:
#          created_at   Chennai
# 5  2024-01-31 08:02  2.705852
# 8  2024-01-31 08:04  2.705852

# %%
#finding out pollution level at Mumbai by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':12})
x =pd.to_datetime(df['created_at'])
y=df['Mumbai']
plt.plot_date(x, y,color='yellow')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Mumbai")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Mumbai')

# %%
#finding out pollution level at Hyderabad by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':12})
x =pd.to_datetime(df['created_at'])
y=df['Hyderabad']
plt.plot_date(x, y,color='green')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Hyderabad")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Hyderabad')

# %%
#finding out pollution level at Hyderabad by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':12})
x =pd.to_datetime(df['created_at'])
y=df['Hyderabad']
plt.plot_date(x, y,color='red')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Chennai ")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Chennai ')

# %%
#finding out pollution level at Chennai by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':12})
x =pd.to_datetime(df['created_at'])
y=df['Chennai']
plt.plot_date(x, y,color='red')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Chennai")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Chennai')

# %%
#pairplotting
sns.set(font_scale=1.5)
g=sns.pairplot(df,hue="Mumbai")
g.fig.set_size_inches(10,10)

# %%
sns.jointplot(x="Mumbai",y="Hyderabad",data=df,color='yellow')

# %%
sns.jointplot(x="Mumbai",y="Chennai",data=df,color='green')

# %%
sns.jointplot(x="Chennai",y="Hyderabad",data=df,color='red')
